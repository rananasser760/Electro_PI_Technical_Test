# %%
# !pip install -q transformers accelerate bitsandbytes sentencepiece
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 12.7 MB/s eta 0:00:00

# %%
# !python benchmark.py --mode fp16
# Out:
# Loading Qwen/Qwen2.5-1.5B-Instruct in fp16 mode...
# config.json: 100% 660/660 [00:00<00:00, 3.19MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 19.6MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 62.2MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 80.8MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 107MB/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# model.safetensors: downloading bytes:   0% 0.00/3.09G [00:00<?, ?B/s]
# model.safetensors: downloading bytes:   6% 174M/3.09G [00:01<00:15, 192MB/s, 14.1MB/s  ]
# model.safetensors: reconstructing file:   4% 131M/3.09G [00:02<00:42, 69.3MB/s, 4.26kB/s  ]
# model.safetensors: reconstructing file:   5% 158M/3.09G [00:02<00:35, 83.0MB/s, 12.5MB/s  ]
# model.safetensors: downloading bytes:   8% 249M/3.09G [00:02<00:17, 163MB/s, 19.9MB/s  ]
# model.safetensors: downloading bytes:   9% 276M/3.09G [00:02<00:18, 152MB/s, 24.1MB/s  ]
# model.safetensors: downloading bytes:  10% 309M/3.09G [00:02<00:17, 156MB/s, 25.8MB/s  ]
# model.safetensors: downloading bytes:  12% 381M/3.09G [00:03<00:22, 121MB/s, 28.6MB/s  ]
# model.safetensors: downloading bytes:  26% 815M/3.09G [00:05<00:06, 347MB/s, 62.9MB/s  ]
# model.safetensors: downloading bytes:  29% 908M/3.09G [00:05<00:11, 191MB/s, 69.0MB/s  ]
# model.safetensors: downloading bytes:  34% 1.06G/3.09G [00:06<00:11, 181MB/s, 76.0MB/s  ]
# model.safetensors: downloading bytes:  39% 1.21G/3.09G [00:07<00:08, 232MB/s, 85.6MB/s  ]
# model.safetensors: downloading bytes:  48% 1.47G/3.09G [00:08<00:08, 190MB/s, 99.4MB/s  ]
# model.safetensors: downloading bytes:  57% 1.77G/3.09G [00:09<00:06, 197MB/s,  112MB/s  ]
# model.safetensors: downloading bytes:  60% 1.87G/3.09G [00:10<00:09, 133MB/s,  112MB/s  ]
# model.safetensors: downloading bytes:  64% 1.96G/3.09G [00:11<00:11, 96.1MB/s,  111MB/s  ]
# model.safetensors: reconstructing file:  57% 1.75G/3.09G [00:11<00:06, 203MB/s, 93.1MB/s  ]
# model.safetensors: downloading bytes:  66% 2.02G/3.09G [00:11<00:08, 126MB/s,  112MB/s  ]
# model.safetensors: downloading bytes:  74% 2.30G/3.09G [00:13<00:03, 252MB/s,  120MB/s  ]
# model.safetensors: downloading bytes:  86% 2.64G/3.09G [00:14<00:02, 200MB/s,  134MB/s  ]
# model.safetensors: downloading bytes:  87% 2.69G/3.09G [00:15<00:02, 160MB/s,  135MB/s  ]
# model.safetensors: reconstructing file:  76% 2.34G/3.09G [00:17<00:06, 117MB/s,  113MB/s  ]
# model.safetensors: reconstructing file:  85% 2.61G/3.09G [00:17<00:02, 171MB/s,  109MB/s  ]
# model.safetensors: reconstructing file:  91% 2.82G/3.09G [00:18<00:01, 190MB/s,  125MB/s  ]
# model.safetensors: downloading bytes: 100% 2.69G/2.69G [00:21<00:00, 128MB/s,  133MB/s  ]
# model.safetensors: reconstructing file: 100% 3.09G/3.09G [00:21<00:00, 146MB/s,  129MB/s  ]
# Loading weights: 100% 338/338 [00:07<00:00, 45.22it/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.57MB/s]
# Loaded. Memory after load: 3.09 GB
#
# [1/5] 14.16 tok/s
# Q: Explain the difference between a list and a tuple in Python in two sentences.
# A: In Python, a list is an ordered collection of items that can be modified, while a tuple is an immutable sequence of items. Lists are defined using square brackets [], whereas tuples use parentheses ().
#
# [2/5] 24.56 tok/s
# Q: Write a short haiku about autumn rain.
# A: Autumn's gentle shower,
# Leaves whisper to the ground,
# Nature's soft sigh.
#
# [3/5] 26.03 tok/s
# Q: A customer says their food delivery is 40 minutes late. Write a brief, empathetic reply.
# A: I'm sorry to hear that your order was delayed. I hope you're able to enjoy it soon and have a pleasant experience with our service. Please let me know if there's anything we can do to improve the situation for future deliveries.
#
# [4/5] 22.83 tok/s
# Q: Summarize in one paragraph why quantization reduces a neural network's memory footprint.
# A: Quantization is a technique used to reduce the memory footprint of neural networks by reducing the precision with which weights and activations are represented. By using fewer bits to represent these values, the amount of storage required for the model can be significantly reduced. This is particularly useful when deploying models on devices with limited resources such as mobile phones or embedded systems where high computational power is not available. Additionally, quantization helps in speeding up inference times since it requires less computation to perform operations on lower-precision data types. Overall, quantization enables more efficient use of hardware resources while maintaining acceptable levels of accuracy, making it an essential tool in modern deep learning applications.
#
# [5/5] 24.5 tok/s
# Q: Translate this sentence to French: 'The restaurant is closed on Mondays.'
# A: Le restaurant est fermé lundi.
#
# === fp16 summary ===
# Peak memory: 3.11 GB
# Avg throughput: 22.42 tok/s
# Saved to results/fp16_results.json

# %%
# !python benchmark.py --mode int4
# Out:
# Loading Qwen/Qwen2.5-1.5B-Instruct in int4 mode...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0% 1/338 [00:00<00:39,  8.43it/s]/usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Loading weights: 100% 338/338 [00:01<00:00, 284.82it/s]
# Loaded. Memory after load: 1.18 GB
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
#
# [1/5] 11.2 tok/s
# Q: Explain the difference between a list and a tuple in Python in two sentences.
# A: In Python, a list is an ordered collection of items that can be modified, while a tuple is also an ordered collection of items but it cannot be modified after creation. Lists are represented with square brackets [], whereas tuples are represented with parentheses ().
#
# [2/5] 12.3 tok/s
# Q: Write a short haiku about autumn rain.
# A: Autumn's gentle shower,
# Leaves whisper in the cool drizzle,
# Nature's symphony.
#
# [3/5] 10.34 tok/s
# Q: A customer says their food delivery is 40 minutes late. Write a brief, empathetic reply.
# A: I'm really sorry to hear that your order was delayed. I hope the restaurant can handle it and apologize for any inconvenience caused. Please let me know if there's anything else you need from our side. Thank you for understanding.
#
# [4/5] 11.43 tok/s
# Q: Summarize in one paragraph why quantization reduces a neural network's memory footprint.
# A: Quantization is a technique used to reduce the memory footprint of neural networks by converting floating-point numbers into integers or fixed-point numbers. This process involves mapping the range of values that can be represented by a floating-point number onto a smaller set of discrete values, typically within an 8-bit, 16-bit, or 32-bit integer format. By doing so, it significantly decreases the amount of storage required for the weights and activations in the neural network, thereby reducing its overall memory footprint without compromising performance. This makes quantized models more efficient and suitable for deployment on devices with limited computational resources such as smartphones and embedded systems.
#
# [5/5] 11.19 tok/s
# Q: Translate this sentence to French: 'The restaurant is closed on Mondays.'
# A: La maison de restauration est fermée les lundis.
#
# === int4 summary ===
# Peak memory: 1.22 GB
# Avg throughput: 11.29 tok/s
# Saved to results/int4_results.json
